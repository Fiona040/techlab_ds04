# %%
import pandas as pd
import numpy as np
data = pd.read_csv("/Users/arsenbity/Desktop/techlab_ds04/datasets/rejected_2007_to_2018Q4-2.csv")

data.shape 
data.head 
data.sample(5)
data.sample(5)

data.info()

data.describe()

pd.isnull(data).head()

data.sample(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27648741 entries, 0 to 27648740
# Data columns (total 9 columns):
#  #   Column                Dtype
# ---  ------                -----
#  0   Amount Requested      float64
#  1   Application Date      object
#  2   Loan Title            object
#  3   Risk_Score            float64
#  4   Debt-To-Income Ratio  object
#  5   Zip Code              object
#  6   State                 object
#  7   Employment Length     object
#  8   Policy Code           float64
# dtypes: float64(3), object(6)
# memory usage: 1.9+ GB
#           Amount Requested Application Date          Loan Title  Risk_Score  \
# 25001673            2000.0       2017-04-27  Debt consolidation       628.0
# 8777287             2000.0       2014-08-01                 car       709.0
# 6074261            10000.0       2018-08-29  Debt consolidation         NaN
# 21844807            3000.0       2015-01-18  debt_consolidation       635.0
# ...
